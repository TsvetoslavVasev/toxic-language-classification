# %%
import re
from lxml import html
import requests
import pandas as pd

def clean_text(text):
    text = re.sub(r'\n+|\t+', ' ', text)
    text = re.sub(r'Share on Facebook', '', text)
    text = text.strip()
    return text

def filter_sentences(sentences):
    filtered = []
    for sentence in sentences:
        filtered.append(sentence)
    return filtered

def simple_sentence_splitter(text):
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return [sentence.strip() for sentence in sentences if sentence]

def fetch_article_sentences(url, max_sentences=1000):
    sentences = []
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}, stopping...")
        return sentences

    tree = html.fromstring(response.content)
    post_bodies = tree.xpath('//div[contains(@class, "entry-content")]/p')

    for post in post_bodies:
        text = post.text_content().strip()
        text = clean_text(text)
        post_sentences = simple_sentence_splitter(text)
        post_sentences = filter_sentences(post_sentences)
        sentences.extend(post_sentences)
        if len(sentences) >= max_sentences:
            break
    return sentences[:max_sentences]

urls = [
    'https://proud.bg/kak-da-pravim-seks-s-trans-partnyori-saveti-ot-trans-momiche/',
    'https://proud.bg/translation-yanuarsko-razstrelvane-na-biologichnia-pol/',
    'https://proud.bg/doklad-trima-ot-chetirima-sa-bili-tormozeni-v-uchilishte-zaradi-polova-identichnost/',
    'https://proud.bg/sofia-prayd-otbelyaza-mezhdunarodnia-den-sreshtu-homofobiata-bifobiata-i-transfobiata/',
    'https://proud.bg/evropa-ne-e-podgotvena-sreshtu-atakite-na-kraynata-desnitsa/',
    'https://proud.bg/my-voice-my-choice-initsiativa-za-pravoto-na-bezopasen-i-dostapen-abort/',
    'https://proud.bg/baydan-finalizira-mashtabni-promeni-v-zakona-za-zashtita-ot-diskriminatsia/',
    'https://proud.bg/konkurs-za-poezia-v-rusia-vavede-zabrana-za-uchastie-na-trans-hora/',
    'https://proud.bg/irak-otlaga-glasuvaneto-na-zakonoproekt-predvizhdasht-smartno-nakazanie-za-ednopolovi-otnoshenia/',
    'https://proud.bg/tayland-se-doblizhava-do-legaliziraneto-na-ednopolovite-sayuzi/',
    'https://proud.bg/gana-e-blizo-do-priemaneto-na-strog-anti-lgbti-zakon/',
    'https://proud.bg/gartsia-legalizira-ednopolovite-brakove/',
    'https://proud.bg/kak-da-badesh-po-dobar-pasiven-v-legloto/',
    'https://proud.bg/seks-saveti-za-neopitnite-gey-mazhe/',
    'https://proud.bg/zhenite-koito-pravyat-seks-s-zheni-svarshv/',
    'https://proud.bg/dopitvane-razkri-che-chetvart-ot-porno-d/',
    'https://proud.bg/kolko-riskov-e-oralniat-seks/',
    'https://proud.bg/kak-da-badesh-po-dobar-aktiven-v-legloto/',
    'https://proud.bg/nasheto-semeystvo-se-radva-na-prava-koito-ne-bihme-imali-v-balgaria/',
    'https://proud.bg/izraelski-lekari-i-zdravni-rabotnitsi-se-protivopostavyat-na-anti-lgbti-prizivite-na-pravitelstvoto/'

]

all_sentences = []

for url in urls:
    collected_sentences = fetch_article_sentences(url)
    all_sentences.extend(collected_sentences)
    print(f"Total sentences collected from {url}: {len(collected_sentences)}")

print(f"Total sentences collected from all URLs: {len(all_sentences)}")
print(all_sentences)

df = pd.DataFrame({
    'text': all_sentences,
    'Toxic': 0,
    'MedicalTerminology': 0,
    'NonToxic': 0,
    'MinorityGroup': 0,
    'sentence_length': [len(sentence) for sentence in all_sentences]
})

df.to_csv('../data/scraped_datasets/proud_bg_sentences.csv', index=False)
print("CSV file has been created with the collected sentences.")
# Out:
# Total sentences collected from https://proud.bg/kak-da-pravim-seks-s-trans-partnyori-saveti-ot-trans-momiche/: 22
# Total sentences collected from https://proud.bg/translation-yanuarsko-razstrelvane-na-biologichnia-pol/: 29
# Total sentences collected from https://proud.bg/doklad-trima-ot-chetirima-sa-bili-tormozeni-v-uchilishte-zaradi-polova-identichnost/: 29
# Total sentences collected from https://proud.bg/sofia-prayd-otbelyaza-mezhdunarodnia-den-sreshtu-homofobiata-bifobiata-i-transfobiata/: 21
# Total sentences collected from https://proud.bg/evropa-ne-e-podgotvena-sreshtu-atakite-na-kraynata-desnitsa/: 40
# Total sentences collected from https://proud.bg/my-voice-my-choice-initsiativa-za-pravoto-na-bezopasen-i-dostapen-abort/: 10
# Total sentences collected from https://proud.bg/baydan-finalizira-mashtabni-promeni-v-zakona-za-zashtita-ot-diskriminatsia/: 5
# Total sentences collected from https://proud.bg/konkurs-za-poezia-v-rusia-vavede-zabrana-za-uchastie-na-trans-hora/: 6
# Total sentences collected from https://proud.bg/irak-otlaga-glasuvaneto-na-zakonoproekt-predvizhdasht-smartno-nakazanie-za-ednopolovi-otnoshenia/: 6
# Total sentences collected from https://proud.bg/tayland-se-doblizhava-do-legaliziraneto-na-ednopolovite-sayuzi/: 4
# Total sentences collected from https://proud.bg/gana-e-blizo-do-priemaneto-na-strog-anti-lgbti-zakon/: 8
# Total sentences collected from https://proud.bg/gartsia-legalizira-ednopolovite-brakove/: 17
# Total sentences collected from https://proud.bg/kak-da-badesh-po-dobar-pasiven-v-legloto/: 55
# Total sentences collected from https://proud.bg/seks-saveti-za-neopitnite-gey-mazhe/: 46
# Total sentences collected from https://proud.bg/zhenite-koito-pravyat-seks-s-zheni-svarshv/: 13
# Total sentences collected from https://proud.bg/dopitvane-razkri-che-chetvart-ot-porno-d/: 6
# Total sentences collected from https://proud.bg/kolko-riskov-e-oralniat-seks/: 23
# Total sentences collected from https://proud.bg/kak-da-badesh-po-dobar-aktiven-v-legloto/: 56
# Total sentences collected from https://proud.bg/nasheto-semeystvo-se-radva-na-prava-koito-ne-bihme-imali-v-balgaria/: 30
# Total sentences collected from https://proud.bg/izraelski-lekari-i-zdravni-rabotnitsi-se-protivopostavyat-na-anti-lgbti-prizivite-na-pravitelstvoto/: 10
# Total sentences collected from all URLs: 436
# ['Харесвате си транс мацка и искате да правите секс с нея, но не сте сигурни какво би я задоволило или как да не я обидите, тъй като не се чувствате добре запознати?', 'Това е статията за вас.', '(Любопитните също са добре дошли!)', 'Нечесто се натъквам на коментари от мъже, които са попаднали в неловки секс ситуации или не разбират къде грешат, стане ли въпрос за транс секс.', 'Толкова много въпроси изникват при много стрейт или би/пан мъже: как да се отнеса с уважение?', 'Какво би й харесало?', 'Дали мога да я нарека ____ без да прегазя лука?', 'Отговорът на всичко това, дори да не сте силно информирани с детайли около транс идентичностите е много прост.', 'Просто следваме едничкото правило за добър секс като цяло – а това е добра КОМУНИКАЦИЯ.', 'Страх ви е да питате?', 'Питайте.', 'Давам ви гаранция, че резултатът от това ще е поне 10 пъти по-задоволителен от това да премълчите и да сгафите с нещо, което партньорката ви всъщност не намира за особено привличащо.', 'Изговорете всички притеснения и когато всичко е на една страница – тогава е време да започнете.', 'Ето все пак и някои неща, които е добре да се вземат предвид:', 'Не по-малко важно от всичко останало е, да се уверите, че сте запознати с местоименията на партньора ви – кофти изказвания по време на секс могат тотално да убият настроението и атмосферата.', 'Покажете, че ви пука.', 'Важно е.', 'Ако се чудите как да се отнесете с транс момиче например – нека не забравяме, че да правите секс с нея, не е по-различно от това да правите секс с което и да е друго момиче – подходете по такъв начин и с тази менталност.', 'Ако сте мъж – да правите секс с транс момиче, не е нещо “гей“ и определено не е “фетиш“ (независимо какво сте чули).', 'Транс хората сме човешки същества като всички други и не очакваме по-специално отношение.', 'Очакваме човешко такова.', 'И го заслужаваме.', 'Нова година – нов #TRANSlation.', 'След цялата трансфобия, която се изля от личности като J.', 'K.', 'Rowling и след решението на Конституционния съд у нас наистина се замислих, колко много на всички ни е писнало да чуваме за “биологичният пол“.', 'Всъщност, ако дисектираме достатъчно разбиранията и твърденията на повечето хора за него, ще осъзнаем, че той реално НЕ СЪЩЕСТВУВА.', 'Нека погледнем разни мнения, които често срещам (перифразирани и лишени от циничност):', 'Това далеч не е така.', 'Според статистики около 2% (колкото е и популацията на червенокоси хора) от населението на земята се ражда интерсекс и има отличителни белези и от двата пола, което е само една от причините принизяването на биологичният пол до гениталиите на човек да е меко казано абсурдно.', 'Какво се случва с всеки от нас там долу е нещо изключително лично и често хората стрелят с грешни предположения.', 'Всъщност именно това погрешно разбиране причинява много болка не само за транс, но и за интерсекс хората, защото често докторите си позволяват да правят хирургична намеса по собствена преценка, там където не трябва.', 'Няма как да създадеш биологичният пол на чужд човек, само защото искаш да го поставиш в рамка.', 'Това е друго нещо, което чувам често.', 'Всъщност на английски вече се популяризират термините AFAB и AMAB – Assigned Female at Birth и Assigned Male at Birth и това се случва с причина.', 'Може би това е нещото, което всъщност се търси в случая и липсва, а спокойно може да фигурира в медицински документи.', 'Разбирането за пол и липсата на разграничаването на пол и sex в България създава множество обърквания.', 'Фигурирането на нещо подобно в документите трябва да е силно лично и конфиденциално.', 'Единствено трябва да сме отворени и готови за промяна.', 'Грешно!', 'Транс хора винаги са съществували, но историците често пренебрегват или умишлено заличават всякакви признаци за нас.', 'ЛГБТ заличаване (Queer erasure) от историята като цяло ражда такива разбирания, но те не са факти.', 'Под един ъгъл – той не съществува.', 'Всички ние сме едни небинарни човешки същества, които бродим и кретаме по тази земя с всякакв ...
# CSV file has been created with the collected sentences.
